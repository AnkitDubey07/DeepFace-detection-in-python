# %%
pip install deepface
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: click>=5.1 in d:\downloads\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (7.1.2)
# ...
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
from deepface import DeepFace

# %%
img1 = 'D:\deepface\deepika.jpg'
img2 = 'D:\deepface\Kareena-kapoor.jpg'

# %%
resp = DeepFace.verify(img1_path=img1,img2_path=img2,enforce_detection=False)

# %%
resp
# Out:
# {'verified': False,
#  'distance': 0.4766040524896423,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}

# %%
img=DeepFace.analyze(img_path=img1,enforce_detection=False)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:08<00:00,  2.12s/it]

# %%
img
# Out:
# {'emotion': {'angry': 4.8954018616598205e-08,
#   'disgust': 2.0762494645812804e-20,
#   'fear': 0.0019620640159700997,
#   'happy': 7.803281576457266e-07,
#   'sad': 99.96554851531982,
#   'surprise': 4.6555451551147375e-11,
#   'neutral': 0.03248875727877021},
#  'dominant_emotion': 'sad',
#  'region': {'x': 0, 'y': 0, 'w': 572, 'h': 467},
#  'age': 33,
#  'gender': 'Woman',
#  'race': {'asian': 6.714836563448496,
#   'indian': 12.909604657841284,
#   'black': 3.4928005627155976,
#   'white': 34.18279101643455,
#   'middle eastern': 11.192403577852676,
#   'latino hispanic': 31.50757032723073},
#  'dominant_race': 'white'}

# %%
img1 = DeepFace.detectFace(img1,enforce_detection=False)

# %%
plt.imshow(img1)

# %%
img2 = DeepFace.detectFace(img2,enforce_detection=False)

# %%
plt.imshow(img2)
